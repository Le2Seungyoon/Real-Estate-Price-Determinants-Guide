# %%
import pandas as pd
# Out:
# C:\Users\chanw\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# !pip install pandas==3.0.0
# Out:
# ERROR: Could not find a version that satisfies the requirement pandas==3.0.0 (from versions: 0.1, 0.2, 0.3.0, 0.4.0, 0.4.1, 0.4.2, 0.4.3, 0.5.0, 0.6.0, 0.6.1, 0.7.0, 0.7.1, 0.7.2, 0.7.3, 0.8.0, 0.8.1, 0.9.0, 0.9.1, 0.10.0, 0.10.1, 0.11.0, 0.12.0, 0.13.0, 0.13.1, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.15.2, 0.16.0, 0.16.1, 0.16.2, 0.17.0, 0.17.1, 0.18.0, 0.18.1, 0.19.0, 0.19.1, 0.19.2, 0.20.0, 0.20.1, 0.20.2, 0.20.3, 0.21.0, 0.21.1, 0.22.0, 0.23.0, 0.23.1, 0.23.2, 0.23.3, 0.23.4, 0.24.0, 0.24.1, 0.24.2, 0.25.0, 0.25.1, 0.25.2, 0.25.3, 1.0.0, 1.0.1, 1.0.2, 1.0.3, 1.0.4, 1.0.5, 1.1.0, 1.1.1, 1.1.2, 1.1.3, 1.1.4, 1.1.5, 1.2.0, 1.2.1, 1.2.2, 1.2.3, 1.2.4, 1.2.5, 1.3.0, 1.3.1, 1.3.2, 1.3.3, 1.3.4, 1.3.5, 1.4.0rc0, 1.4.0, 1.4.1, 1.4.2, 1.4.3, 1.4.4, 1.5.0rc0, 1.5.0, 1.5.1)
# ERROR: No matching distribution found for pandas==3.0.0

# %%
# !conda install -c conda-forge pycaret

# %%
# !pip install pycaret
# Out:
# ...
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# ...
#   Using cached cufflinks-0.17.3.tar.gz (81 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached umap-learn-0.5.3.tar.gz (88 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 9.1/9.1 MB 10.1 MB/s eta 0:00:00
# ...
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# ...
#      ---------------------------------------- 2.3/2.3 MB 9.8 MB/s eta 0:00:00
# ...
#   Using cached yellowbrick-1.5-py3-none-any.whl (282 kB)
# ...
#      ---------------------------------------- 31.4/31.4 MB 9.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.2/7.2 MB 10.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
# ...

# %%
from pycaret.regression import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16216\215956045.py in <module>
# ----> 1 from pycaret.regression import *
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
df = pd.read_csv("./아파트 가격/2021실거래가_처리후.csv", encoding='cp949')

# %%
df #땅의 종류에 대한 카테고리 유형을 나누는 변수가 들어가야 함 - 네이버 부동산 / 지도 찾아보기 (땅의 용도 구분)
# Out:
#            계약일자    구    동      번지     본번    부번             단지명  전용면적(㎡)  \
# 0      20210415  강남구  개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75
# 1      20210515  강남구  개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97
# 2      20210811  강남구  개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97
# 3      20210902  강남구  개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97
# 4      20211204  강남구  개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97
# ...         ...  ...  ...     ...    ...   ...             ...      ...
# 43408  20210227  중랑구  중화동  274-51  274.0  51.0         한영(101)    57.66
# 43409  20211104  중랑구  중화동  274-51  274.0  51.0         한영(101)    84.69
# 43410  20210504  중랑구  중화동  274-75  274.0  75.0         한영(102)    72.22
# 43411  20210701  중랑구  중화동  274-76  274.0  76.0         한영(103)    58.46
# 43412  20210820  중랑구  중화동  274-76  274.0  76.0         한영(103)   104.93
#
#        거래금액(만원)  층  건축년도         도로명  해제사유발생일  거래유형
# ...

# %%
df[["계약일자", "구", "동", "전용면적(㎡)", "거래금액(만원)", "건축년도"]]
# Out:
#            계약일자    구    동  전용면적(㎡)  거래금액(만원)  건축년도
# 0      20210415  강남구  개포동    77.75    174000  1988
# 1      20210515  강남구  개포동    79.97    195000  1987
# 2      20210811  강남구  개포동    79.97    200000  1987
# 3      20210902  강남구  개포동    79.97    220000  1987
# 4      20211204  강남구  개포동    79.97    215000  1987
# ...         ...  ...  ...      ...       ...   ...
# 43408  20210227  중랑구  중화동    57.66     30500  2003
# 43409  20211104  중랑구  중화동    84.69     50000  2003
# 43410  20210504  중랑구  중화동    72.22     49500  2003
# 43411  20210701  중랑구  중화동    58.46     30000  2003
# 43412  20210820  중랑구  중화동   104.93     61500  2003
#
# [43413 rows x 6 columns]

# %%
#동 단위 가격은 유사하다
#다른 데이터 가능한한 동 단위로 데이터 묶는다

#기간은 월 단위로 한정하는게 좋을 듯 싶다 - 년도는 일치화가 필요한다
#가격 데이터: 2021년도?
#거시경제 데이터: 2002~202206

#변수와 같은 경우 선행 연구를 참고해서 선정

#개폐율과 용적율 포함 / 계단식과 미분양?

#인구 비율 변화의 경우 선으로 그리는 그래프가 좋을 듯 싶다

#지하철 역 수는 지하철 승하차 인원으로 대체한다
